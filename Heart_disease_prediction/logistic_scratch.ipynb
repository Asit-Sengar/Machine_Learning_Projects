# %% [markdown]
# in this file i will make logistic regression from scratch

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("heart_disease_dataset.csv")
df.sample(4)
# Out:
#      Age  Gender  Cholesterol  Blood Pressure  Heart Rate  Smoking  \
# 609   43    Male          187             172          80  Current
# 594   52  Female          156             117          63    Never
# 619   59    Male          306             150          89   Former
# 269   65  Female          197             167          87   Former
#
#     Alcohol Intake  Exercise Hours Family History Diabetes Obesity  \
# 609            NaN               8            Yes      Yes      No
# 594       Moderate               5             No       No     Yes
# 619       Moderate               6            Yes      Yes      No
# 269       Moderate               8             No      Yes     Yes
#
#      Stress Level  Blood Sugar Exercise Induced Angina   Chest Pain Type  \
# 609             1          163                      No    Typical Angina
# 594             7          116                      No  Non-anginal Pain
# 619             2           75                     Yes   Atypical Angina
# 269             1           70                      No      Asymptomatic
#
#      Heart Disease
# 609              0
# 594              0
# 619              1
# 269              0

# %%
X = df.select_dtypes(include = ["number"])
Y = df.select_dtypes(include = ["object"])
X_train , X_test , Y_train , Y_test  = train_test_split(X , Y , test_size=0.2 , random_state=42)
